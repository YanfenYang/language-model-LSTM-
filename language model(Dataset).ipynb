# %%
import torchtext
from torchtext.vocab import Vectors
import torch
import numpy as np
import random
import pandas as pd
from torchtext import data
from torchtext.vocab import Vectors
from torch.nn import init
USE_CUDA = torch.cuda.is_available() #判断是否有GPU
from torch.utils.data import Dataset,DataLoader
from collections import Counter #Counter 计数器

random.seed(53113)
np.random.seed(53113)
torch.manual_seed(53113)
if USE_CUDA:
    torch.cuda.manual_seed(53113)

BATCH_SIZE = 32 #一个batch多少个句子
EMBEDDING_SIZE = 200  #每个单词多少维
VOCAB_SZIE = 1499
HIDDEN_SIZE = 200
N_LAYERS = 2

# %%
#句子的最大长度
def max_lens(path):
    len1 = 0
    with open(path,'r',errors='ignore',encoding='utf-8') as f:
        lines=f.readlines()
        for line in lines:
            line=line.split()    
            if len1<len(line):
                len1=len(line)
    return len1

# %%
path1 = r'C:/Users/Aurantius/Desktop/自然语言处理/第二阶段—在线视频学习资料 (3)/language model/bobsue.lm.train.txt'
path2 = r'C:/Users/Aurantius/Desktop/自然语言处理/第二阶段—在线视频学习资料 (3)/language model/bobsue.lm.dev.txt'
path3 = r'C:/Users/Aurantius/Desktop/自然语言处理/第二阶段—在线视频学习资料 (3)/language model/bobsue.lm.test.txt'

test_max_len = max_lens(path3)
dev_max_len = max_lens(path2)
train_max_len = max_lens(path1)
max_len = max(test_max_len,dev_max_len,train_max_len)
print(max_len)
# Out:
# 21

# %%
#处理句子长短不一问题
def context_pad(path):
    context=[]
    with open(path,'r',errors='ignore',encoding='utf-8') as f:
        lines=f.readlines()
        for line in lines:
            line=line.split()
            context.append(line)
    for i in range(len(context)):
        for j in range(len(context[i])) :
            while len(context[i]) < 21:
                context[i].append("<pad>")
            else:
                continue
    return context

# %%
test_pad =  context_pad(path3)
dev_pad =  context_pad(path2)
train_pad =  context_pad(path1)

# %%
#建立词典
#索引到词
def index_word(path):
    vocab = {}
    with open(path,'r',errors='ignore',encoding='utf_8') as f:
        voc = [line.strip('\n') for line in f.readlines()]    
    #    for line in f.readlines():
        vocab[0] = "<pad>"
        for index,word in enumerate(voc):
            vocab[index+1] = word
    return vocab

# %%
def word_index(index_word):    
    word_index = {v : k for k, v in index_word.items()} 
    return word_index

# %%
index_word = index_word('C:/Users/Aurantius/Desktop/自然语言处理/第二阶段—在线视频学习资料 (3)/language model/bobsue.voc.txt')
word_index = word_index(index_word)

# %%
class Languagedataset(Dataset):
    def __init__(self,data,max_len1):
        super(Languagedataset, self).__init__() #初始化模型
        self.data = data    #输入数据
        self.max_len1 = max_len1  #句子长度
        self.dat_n = torch.tensor(self.sentence_vec(),requires_grad = False).long().view(-1,max_len1) 
    def __len__(self): 
        return len(self.data)#返回数据集的长度
    def sentence_vec(self):#句子的向量化
        text = []
        length=0
        for sentence in self.data:
            word = []
            for i in range(len(sentence)):
                word.append(word_index[sentence[i]])
            text.append(word)
        return text
    def __getitem__(self,idx):
        inputs = self.dat_n[:,:-1]
        targets = self.dat_n[:,1:]
        
        inputs = inputs[idx]
        targets = targets[idx]
        return inputs,targets

# %%
train_data= Languagedataset(train_pad,max_len1=max_len)
train_dataloader=DataLoader(train_data,batch_size=BATCH_SIZE,shuffle=False)

dev_data= Languagedataset(dev_pad,max_len1=max_len)
dev_dataloader=DataLoader(dev_data,batch_size=BATCH_SIZE,shuffle=False)

test_data= Languagedataset(test_pad,max_len1=max_len)
test_dataloader=DataLoader(test_data,batch_size=BATCH_SIZE,shuffle=False)

# %%
device = torch.device("cuda" if USE_CUDA else "cpu")

# %%
import torch.nn as nn
class LSTMModel(nn.Module):
    def __init__(self,vocab_size,embed_size,hidden_size,n_layers,dropout):
        super(LSTMModel,self).__init__()  #因为继承了nn.Module,所以这句话必须要写，等价于nn.Module.__init__()
        self.dropout = nn.Dropout(dropout)
        self.embed = nn.Embedding(vocab_size,embed_size,padding_idx = 0)
        self.lstm = nn.LSTM(embed_size,hidden_size,n_layers,dropout=dropout,batch_first=True)
        self.linear = nn.Linear(hidden_size,vocab_size)#隐含层作为输入，然后做线性变化得出y,y为5002维的概率向量
        self.hidden_size = hidden_size
        self.n_layers = n_layers #2
        self.init_weights()   
    def init_weights(self):#各个权重的初始化
        initrange = 0.1
        self.embed.weight.data.uniform_(-initrange, initrange)#词向量层权重的初始化
        self.linear.bias.data.zero_()#线性层偏置的初始化,也可以写为self.sm_fc.bias.data.fill_(0.0)
        self.linear.weight.data.uniform_(-initrange, initrange)#线性层权重的初始化
    def forward(self,text,hidden):
            #forword pass
            #text: seq_length * batch_size
        emb = self.dropout(self.embed(text))#seq_length * batch_size * embed_size
        output,hidden = self.lstm(emb,hidden)
        output = self.dropout(output)
            # output: seq_length * batch_size * hidden_size
            # hidden: (1 * batch_size * hidden_size,1 * batch_size * hidden_size) 一个hidden strate,一个cell state
            # output = (seq_length * batch_size) * hidden_size    因为做线性变换的时候只能取两维的变量。所以做此变换
        out_vocab = self.linear(output.contiguous().view(-1,output.shape[2]))# out_vocab的维度(seq_length * batch_size) * hidden_size ,shape[2]表示把hidden_size固定，其他两个维度合并。
        out_vocab = out_vocab.contiguous().view(output.size(0),output.size(1),out_vocab.size(-1))#还原本来的维度
        return out_vocab,hidden

    def init_hidden(self,bsz,requires_grad=True):
        # hidden strate的初始化一般是全0
        weight = next(self.parameters())#不知道是在cpu还是GPU上运行，所以这样取参数：由于self.parameters()是一个iterator,它相当于模型里的所有参数，这里随便拿一个参数作为hidden strate和cell state的参数，下面全初始化为0
        return (weight.new_zeros((self.n_layers, bsz, self.hidden_size), requires_grad=True),
                weight.new_zeros((self.n_layers, bsz, self.hidden_size), requires_grad=True))#requires_grad表示反向求梯度是否要求到这个地方来，显而易见，h,c是必须要更新的参数，所以设置为True

# %%
model = LSTMModel(vocab_size = VOCAB_SZIE,embed_size = EMBEDDING_SIZE, hidden_size = HIDDEN_SIZE,n_layers=N_LAYERS,dropout=0.5)
if USE_CUDA:
    model = model.to(device)

# %%
loss_fn = nn.CrossEntropyLoss()#交叉熵损失
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.5)
# 每调用一次这个函数，lenrning_rate就降一半，0.5就是一半的意思

# %%
#预测正确率,并将预测错误的词语与真实值打印出来
def Pred_acc(predicts, targets):   
    one_total_count = 0
    one_right_count = 0 
    pre_tar = []
    Column_num = predicts.shape[0]
    Row_num = predicts.shape[1]
    for i in range(Column_num):
        for j in range(Row_num):
            if(targets[i][j].item() == word_index['<pad>']):
                continue
            else:
                one_total_count += 1         
                if(predicts[i][j].item() == targets[i][j].item()):
                    one_right_count += 1
                else:
                    pre = index_word[predicts[i][j].item()]
                    tar = index_word[targets[i][j].item()]
                    pre_tar.append((pre,tar))
    return one_right_count,one_total_count,pre_tar

# %%
def evaluate(model,data):
    model.eval()
    total_loss = 0.
    total_count = 0.#一共预测了多少个单词
    one_batch_right_count = 0
    one_all_count = 0
    all_batch_right_count = 0
    all_batch_all_count = 0 
    pre_tar_total =[] 
    it = iter(data)
    with torch.no_grad():#因为是在预测，不需要反向求梯度。这句话可以不让grading进来
        for i, batch in enumerate(it):
            inputs, targets = batch
            # 取出训练集的输入的数据和输出的数据，相当于特征和标签         
            hidden = model.init_hidden(inputs.size(0), requires_grad=False) # 初始化隐藏状态 
            if USE_CUDA:
                inputs, targets = inputs.cuda(), targets.cuda()
            with torch.no_grad():
                output,hidden = model(inputs,hidden) #调用model的forward方法进行一次前向传播，得到return输出值
            out_idx = output.argmax(dim=2).int()#找到预测值的索引
            one_batch_right_count,one_all_count,one_pre_tar = Pred_acc(out_idx,targets)
            pre_tar_total.append(one_pre_tar)    
            all_batch_right_count += one_batch_right_count            
            all_batch_all_count += one_all_count
            loss = loss_fn(output.view(-1, VOCAB_SIZE), targets.view(-1))# 计算交叉熵的损失是平均过的，这里需要计算下总的损失
            #targets.view(-1).size() = 640,output.view(-1, VOCAB_SIZE).size() = [640,1499]
            # # 每次batch平均后的损失乘以每次batch的样本的总的单词数 = 一次batch总的损失
            total_loss += loss.item()* np.multiply(*inputs.size())   
            # total_count先计算验证集样本的单词总数，一个样本有50个单词，一个batch32个样本
            total_count += np.multiply(*inputs.size())    
            # np.multiply(*data.size()) =50*32=1600               
    loss = total_loss / total_count # 整个验证集总的损失除以总的单词数
  
    model.train()
    return loss,all_batch_right_count/all_batch_all_count,pre_tar_total

# %%
#一个batch一个batch的训练，每个batch中含有32个句子，句子之间相互分开训练的，当时间序列走完后，每个句子都有各自的loss,hidden,cell。
NUM_EPOCHS = 20
GRAD_CLIP = 5.0
VOCAB_SIZE = 1499
val_losses = []
val_best_acc = []
for epoch in range(NUM_EPOCHS):
    model.train() # 训练模式  
    it = iter(train_dataloader)
    for i, batch in enumerate(it):
        inputs, targets = batch
        # 取出训练集的输入的数据和输出的数据，相当于特征和标签
        hidden = model.init_hidden(inputs.size(0)) # 初始化隐藏状态
        if USE_CUDA:
            inputs, targets = inputs.cuda(), targets.cuda()
        model.zero_grad() # 梯度归零，不然每次迭代梯度会累加
        
        output, hidden = model(inputs, hidden)
       
        loss = loss_fn(output.view(-1, VOCAB_SIZE), targets.view(-1))#targets.view(-1).size() = 640,output.view(-1, VOCAB_SIZE).size() = [640,1499]
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
        # 防止梯度爆炸，设定阈值，当梯度大于阈值时，更新的梯度为阈值
        optimizer.step()
        if i % 10 == 0:
            print(i)
            val_loss,val_acc,val_pre_tar = evaluate(model,dev_dataloader)
            print("epoch", epoch, "iteration", i, "validation loss", val_loss,"validation accuracy",val_acc)
            if (len(val_best_acc) == 0) or (val_acc > max(val_best_acc)):
                          
                print("current best accuracy:",val_acc)
            if (len(val_losses) == 0) or (val_loss < min(val_losses)):
                torch.save(model.state_dict(), "lm.pth")# 如果比之前的loss要小，就保存模型 
                print("best model, val loss: ", val_loss,"best model,validation accuracy:",val_acc)
            else: # 否则loss没有降下来，需要优化
                print("learning rate decay")
                scheduler.step() # 自动调整学习率  
                optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
            val_losses.append(val_loss) # 保存每10000次迭代后的验证集损失损失
            val_best_acc.append(val_acc)
# Out:
# 0
# epoch 0 iteration 0 validation loss 2.374570873260498 validation accuracy 0.2351388714339575
# current best accuracy: 0.2351388714339575
# best model, val loss:  2.374570873260498 best model,validation accuracy: 0.2351388714339575
# 10
# epoch 0 iteration 10 validation loss 2.3642201093037922 validation accuracy 0.23564157345733316
# current best accuracy: 0.23564157345733316
# best model, val loss:  2.3642201093037922 best model,validation accuracy: 0.23564157345733316
# 20
# epoch 0 iteration 20 validation loss 2.357499276479085 validation accuracy 0.23576724896317708
# current best accuracy: 0.23576724896317708
# best model, val loss:  2.357499276479085 best model,validation accuracy: 0.23576724896317708
# 30
# epoch 0 iteration 30 validation loss 2.355192289352417 validation accuracy 0.2382807590800553
# current best accuracy: 0.2382807590800553
# best model, val loss:  2.355192289352417 best model,validation accuracy: 0.2382807590800553
# 40
# epoch 0 iteration 40 validation loss 2.3449846522013345 validation accuracy 0.2392861631268066
# current best accuracy: 0.2392861631268066
# best model, val loss:  2.3449846522013345 best model,validation accuracy: 0.2392861631268066
# 50
# epoch 0 iteration 50 validation loss 2.3365848286946616 validation accuracy 0.23953751413849442
# current best accuracy: 0.23953751413849442
# best model, val loss:  2.3365848286946616 best model,validation accuracy: 0.23953751413849442
# 60
# epoch 0 iteration 60 validation loss 2.330256189982096 validation accuracy 0.23878346110343093
# best model, val loss:  2.330256189982096 best model,validation accuracy: 0.23878346110343093
# 70
# epoch 0 iteration 70 validation loss 2.32516845258077 validation accuracy 0.23966318964433833
# current best accuracy: 0.23966318964433833
# best model, val loss:  2.32516845258077 best model,validation accuracy: 0.23966318964433833
# 80
# epoch 0 iteration 80 validation loss 2.3145118408203125 validation accuracy 0.24205102425537262
# current best accuracy: 0.24205102425537262
# best model, val loss:  2.3145118408203125 best model,validation accuracy: 0.24205102425537262
# 90
# epoch 0 iteration 90 validation loss 2.306360066095988 validation accuracy 0.24355913032549956
# current best accuracy: 0.24355913032549956
# best model, val loss:  2.306360066095988 best model,validation accuracy: 0.24355913032549956
# 100
# epoch 0 iteration 100 validation loss 2.2963175760904946 validation accuracy 0.24381048133718738
# current best accuracy: 0.24381048133718738
# best model, val loss:  2.2963175760904946 best model,validation accuracy: 0.24381048133718738
# 110
# epoch 0 iteration 110 validation loss 2.292805906295776 validation accuracy 0.2439361568430313
# current best accuracy: 0.2439361568430313
# best model, val loss:  2.292805906295776 best model,validation accuracy: 0.2439361568430313
# 120
# epoch 0 iteration 120 validation loss 2.2822256905237834 validation accuracy 0.24569561392484604
# current best accuracy: 0.24569561392484604
# best model, val loss:  2.2822256905237834 best model,validation accuracy: 0.24569561392484604
# 130
# epoch 0 iteration 130 validation loss 2.275158098220825 validation accuracy 0.24783209752419252
# current best accuracy: 0.24783209752419252
# best model, val loss:  2.275158098220825 best model,validation accuracy: 0.24783209752419252
# 140
# epoch 0 iteration 140 validation loss 2.2664273993174233 validation accuracy 0.24921452808847555
# current best accuracy: 0.24921452808847555
# best model, val loss:  2.2664273993174233 best model,validation accuracy: 0.24921452808847555
# 150
# epoch 0 iteration 150 validation loss 2.2605856008529663 validation accuracy 0.24758074651250472
# best model, val loss:  2.2605856008529663 best model,validation accuracy: 0.24758074651250472
# 160
# epoch 0 iteration 160 validation loss 2.2512609618504844 validation accuracy 0.25147668719366595
# current best accuracy: 0.25147668719366595
# best model, val loss:  2.2512609618504844 best model,validation accuracy: 0.25147668719366595
# 170
# epoch 0 iteration 170 validation loss 2.2473028395970664 validation accuracy 0.24469020987809476
# best model, val loss:  2.2473028395970664 best model,validation accuracy: 0.24469020987809476
# 180
# epoch 0 iteration 180 validation loss 2.2402761494318644 validation accuracy 0.2509739851702903
# best model, val loss:  2.2402761494318644 best model,validation accuracy: 0.2509739851702903
# 0
# epoch 1 iteration 0 validation loss 2.2316732139587403 validation accuracy 0.25373884629885635
# current best accuracy: 0.25373884629885635
# best model, val loss:  2.2316732139587403 best model,validation accuracy: 0.25373884629885635
# 10
# epoch 1 iteration 10 validation loss 2.223869650204976 validation accuracy 0.25160236269950986
# best model, val loss:  2.223869650204976 best model,validation accuracy: 0.25160236269950986
# 20
# epoch 1 iteration 20 validation loss 2.216003839810689 validation accuracy 0.2534874952871685
# best model, val loss:  2.216003839810689 best model,validation accuracy: 0.2534874952871685
# 30
# epoch 1 iteration 30 validation loss 2.2126641200383506 validation accuracy 0.2533618197813246
# best model, val loss:  2.2126641200383506 best model,validation accuracy: 0.2533618197813246
# 40
# epoch 1 iteration 40 validation loss 2.2051875286102294 validation accuracy 0.2548699258514516
# current best accuracy: 0.2548699258514516
# best model, val loss:  2.2051875286102294 best model,validation accuracy: 0.2548699258514516
# 50
# epoch 1 iteration 50 validation loss 2.1970459451675417 validation accuracy 0.25600100540404674
# current best accuracy: 0.25600100540404674
# best model, val loss:  2.1970459451675417 best model,validation accuracy: 0.25600100540404674
# 60
# epoch 1 iteration 60 validation loss 2.190099843343099 validation accuracy 0.2624104562020862
# current best accuracy: 0.2624104562020862
# best model, val loss:  2.190099843343099 best model,validation accuracy: 0.2624104562020862
# 70
# epoch 1 iteration 70 validation loss 2.1862560008366905 validation accuracy 0.2617820786728667
# best model, val loss:  2.1862560008366905 best model,validation accuracy: 0.2617820786728667
# 80
# epoch 1 iteration 80 validation loss 2.1802287845611574 validation accuracy 0.2625361317079301
# current best accuracy: 0.2625361317079301
# best model, val loss:  2.1802287845611574 best model,validation accuracy: 0.2625361317079301
# 90
# epoch 1 iteration 90 validation loss 2.1722527542114256 validation accuracy 0.26517531733065225
# current best accuracy: 0.26517531733065225
# best model, val loss:  2.1722527542114256 best model,validation accuracy: 0.26517531733065225
# 100
# epoch 1 iteration 100 validation loss 2.1641939725875856 validation accuracy 0.2676888274475305
# current best accuracy: 0.2676888274475305
# best model, val loss:  2.1641939725875856 best model,validation accuracy: 0.2676888274475305
# 110
# epoch 1 iteration 110 validation loss 2.1611487471262616 validation accuracy 0.2663063968832475
# best model, val loss:  2.1611487471262616 best model,validation accuracy: 0.2663063968832475
# 120
# epoch 1 iteration 120 validation loss 2.1538434165318807 validation accuracy 0.26894558250596956
# current best accuracy: 0.26894558250596956
# best model, val loss:  2.1538434165318807 best model,validation accuracy: 0.26894558250596956
# 130
# epoch 1 iteration 130 validation loss 2.1488456614812215 validation accuracy 0.2717104436345356
# current best accuracy: 0.2717104436345356
# best model, val loss:  2.1488456614812215 best model,validation accuracy: 0.2717104436345356
# 140
# epoch 1 iteration 140 validation loss 2.144010395685832 validation accuracy 0.26982531104687696
# best model, val loss:  2.144010395685832 best model,validation accuracy: 0.26982531104687696
# 150
# epoch 1 iteration 150 validation loss 2.1396671419143676 validation accuracy 0.2690712580118135
# best model, val loss:  2.1396671419143676 best model,validation accuracy: 0.2690712580118135
# 160
# epoch 1 iteration 160 validation loss 2.130620741208394 validation accuracy 0.2733442252105065
# current best accuracy: 0.2733442252105065
# best model, val loss:  2.130620741208394 best model,validation accuracy: 0.2733442252105065
# 170
# epoch 1 iteration 170 validation loss 2.124888928413391 validation accuracy 0.26605504587155965
# best model, val loss:  2.124888928413391 best model,validation accuracy: 0.26605504587155965
# 180
# epoch 1 iteration 180 validation loss 2.1202212285995485 validation accuracy 0.27422395375141384
# current best accuracy: 0.27422395375141384
# best model, val loss:  2.1202212285995485 best model,validation accuracy: 0.27422395375141384
# 0
# epoch 2 iteration 0 validation loss 2.112750787417094 validation accuracy 0.2749780067864773
# current best accuracy: 0.2749780067864773
# best model, val loss:  2.112750787417094 best model,validation accuracy: 0.2749780067864773
# 10
# epoch 2 iteration 10 validation loss 2.10877188650767 validation accuracy 0.2740982782455699
# best model, val loss:  2.10877188650767 best model,validation accuracy: 0.2740982782455699
# 20
# epoch 2 iteration 20 validation loss 2.1019789991378786 validation accuracy 0.2756063843156969
# current best accuracy: 0.2756063843156969
# best model, val loss:  2.1019789991378786 best model,validation accuracy: 0.2756063843156969
# 30
# epoch 2 iteration 30 validation loss 2.100725363413493 validation accuracy 0.27535503330400907
# best model, val loss:  2.100725363413493 best model,validation accuracy: 0.27535503330400907
# 40
# epoch 2 iteration 40 validation loss 2.0950925410588583 validation accuracy 0.2769888148799799
# current best accuracy: 0.2769888148799799
# best model, val loss:  2.0950925410588583 best model,validation accuracy: 0.2769888148799799
# 50
# epoch 2 iteration 50 validation loss 2.0901904099782307 validation accuracy 0.2778685434208873
# current best accuracy: 0.2778685434208873
# best model, val loss:  2.0901904099782307 best model,validation accuracy: 0.2778685434208873
# 60
# epoch 2 iteration 60 validation loss 2.0866409352620443 validation accuracy 0.27962800050270203
# current best accuracy: 0.27962800050270203
# best model, val loss:  2.0866409352620443 best model,validation accuracy: 0.27962800050270203
# 70
# epoch 2 iteration 70 validation loss 2.082929586728414 validation accuracy 0.28038205353776546
# current best accuracy: 0.28038205353776546
# best model, val loss:  2.082929586728414 best model,validation accuracy: 0.28038205353776546
# 80
# epoch 2 iteration 80 validation loss 2.0784235967000324 validation accuracy 0.28339826567801935
# current best accuracy: 0.28339826567801935
# best model, val loss:  2.0784235967000324 best model,validation accuracy: 0.28339826567801935
# 90
# epoch 2 iteration 90 validation loss 2.0744769798914593 validation accuracy 0.28566042478320974
# current best accuracy: 0.28566042478320974
# best model, val loss:  2.0744769798914593 best model,validation accuracy: 0.28566042478320974
# 100
# epoch 2 iteration 100 validation loss 2.0681866388320924 validation accuracy 0.2861631268065854
# current best accuracy: 0.2861631268065854
# best model, val loss:  2.0681866388320924 best model,validation accuracy: 0.2861631268065854
# 110
# epoch 2 iteration 110 validation loss 2.067632980028788 validation accuracy 0.28452934523061457
# best model, val loss:  2.067632980028788 best model,validation accuracy: 0.28452934523061457
# 120
# epoch 2 iteration 120 validation loss 2.06537473487854 validation accuracy 0.2854090737715219
# best model, val loss:  2.06537473487854 best model,validation accuracy: 0.2854090737715219
# 130
# epoch 2 iteration 130 validation loss 2.060888082186381 validation accuracy 0.28264421264295586
# best model, val loss:  2.060888082186381 best model,validation accuracy: 0.28264421264295586
# 140
# epoch 2 iteration 140 validation loss 2.061744545618693 validation accuracy 0.28214151061958026
# learning rate decay
# 150
# epoch 2 iteration 150 validation loss 2.0655364774068197 validation accuracy 0.28126178207867286
# learning rate decay
# 160
# epoch 2 iteration 160 validation loss 2.0720298725763957 validation accuracy 0.2854090737715219
# learning rate decay
# 170
# epoch 2 iteration 170 validation loss 2.0786461833318075 validation accuracy 0.28201583511373635
# learning rate decay
# 180
# epoch 2 iteration 180 validation loss 2.0815698181788127 validation accuracy 0.2850320472539902
# learning rate decay
# 0
# epoch 3 iteration 0 validation loss 2.0847453918457033 validation accuracy 0.285283398265678
# learning rate decay
# 10
# epoch 3 iteration 10 validation loss 2.0902546116511025 validation accuracy 0.2877969083825562
# current best accuracy: 0.2877969083825562
# learning rate decay
# 20
# epoch 3 iteration 20 validation loss 2.0961295512517295 validation accuracy 0.28415231871308283
# learning rate decay
# 30
# epoch 3 iteration 30 validation loss 2.097564889907837 validation accuracy 0.28566042478320974
# learning rate decay
# 40
# epoch 3 iteration 40 validation loss 2.1052517108917237 validation accuracy 0.28591177579489757
# learning rate decay
# 50
# epoch 3 iteration 50 validation loss 2.106192737897237 validation accuracy 0.28339826567801935
# learning rate decay
# 60
# epoch 3 iteration 60 validation loss 2.1089360265731814 validation accuracy 0.285283398265678
# learning rate decay
# 70
# epoch 3 iteration 70 validation loss 2.1147197612126667 validation accuracy 0.2864144778182732
# learning rate decay
# 80
# epoch 3 iteration 80 validation loss 2.119387527147929 validation accuracy 0.2882996104059319
# current best accuracy: 0.2882996104059319
# learning rate decay
# 90
# epoch 3 iteration 90 validation loss 2.1179010985692344 validation accuracy 0.2882996104059319
# learning rate decay
# 100
# epoch 3 iteration 100 validation loss 2.122325867652893 validation accuracy 0.2898077164760588
# current best accuracy: 0.2898077164760588
# learning rate decay
# 110
# epoch 3 iteration 110 validation loss 2.1216626551946005 validation accuracy 0.2884252859117758
# learning rate decay
# 120
# epoch 3 iteration 120 validation loss 2.1232782996495563 validation accuracy 0.2885509614176197
# learning rate decay
# 130
# epoch 3 iteration 130 validation loss 2.1287894016901654 validation accuracy 0.28578610028905366
# learning rate decay
# 140
# epoch 3 iteration 140 validation loss 2.128715598106384 validation accuracy 0.2884252859117758
# learning rate decay
# 150
# epoch 3 iteration 150 validation loss 2.1312956425348917 validation accuracy 0.28553474927736583
# learning rate decay
# 160
# epoch 3 iteration 160 validation loss 2.132431888580322 validation accuracy 0.28591177579489757
# learning rate decay
# 170
# epoch 3 iteration 170 validation loss 2.13031640179952 validation accuracy 0.2871685308533367
# learning rate decay
# 180
# epoch 3 iteration 180 validation loss 2.132957402229309 validation accuracy 0.2862888023124293
# learning rate decay
# 0
# epoch 4 iteration 0 validation loss 2.1327286065419515 validation accuracy 0.2874198818650245
# learning rate decay
# 10
# epoch 4 iteration 10 validation loss 2.13123686504364 validation accuracy 0.2882996104059319
# learning rate decay
# 20
# epoch 4 iteration 20 validation loss 2.1307571929295857 validation accuracy 0.28591177579489757
# learning rate decay
# 30
# epoch 4 iteration 30 validation loss 2.130935274759928 validation accuracy 0.2886766369234636
# learning rate decay
# 40
# epoch 4 iteration 40 validation loss 2.1312278960545856 validation accuracy 0.2877969083825562
# learning rate decay
# 50
# epoch 4 iteration 50 validation loss 2.13017568620046 validation accuracy 0.2837752921955511
# learning rate decay
# 60
# epoch 4 iteration 60 validation loss 2.13003858534495 validation accuracy 0.28566042478320974
# learning rate decay
# 70
# epoch 4 iteration 70 validation loss 2.1343648239771524 validation accuracy 0.2882996104059319
# learning rate decay
# 80
# epoch 4 iteration 80 validation loss 2.135956288655599 validation accuracy 0.2905617695111223
# current best accuracy: 0.2905617695111223
# learning rate decay
# 90
# epoch 4 iteration 90 validation loss 2.130522585550944 validation accuracy 0.29043609400527837
# learning rate decay
# 100
# epoch 4 iteration 100 validation loss 2.1324760179519653 validation accuracy 0.2905617695111223
# learning rate decay
# 110
# epoch 4 iteration 110 validation loss 2.128865680058797 validation accuracy 0.2919442000754053
# current best accuracy: 0.2919442000754053
# learning rate decay
# 120
# epoch 4 iteration 120 validation loss 2.129145273844401 validation accuracy 0.290938796028654
# learning rate decay
# 130
# epoch 4 iteration 130 validation loss 2.1322114642461143 validation accuracy 0.2915671735578736
# learning rate decay
# 140
# epoch 4 iteration 140 validation loss 2.13673047097524 validation accuracy 0.2899333919819027
# learning rate decay
# 150
# epoch 4 iteration 150 validation loss 2.1340040203730264 validation accuracy 0.2871685308533367
# learning rate decay
# 160
# epoch 4 iteration 160 validation loss 2.1299265848795574 validation accuracy 0.29181852456956137
# learning rate decay
# 170
# epoch 4 iteration 170 validation loss 2.1294532295862836 validation accuracy 0.28817393490008797
# learning rate decay
# 180
# epoch 4 iteration 180 validation loss 2.129998687744141 validation accuracy 0.28892798793515145
# learning rate decay
# 0
# epoch 5 iteration 0 validation loss 2.127487601280212 validation accuracy 0.2920698755812492
# current best accuracy: 0.2920698755812492
# learning rate decay
# 10
# epoch 5 iteration 10 validation loss 2.1247524461746217 validation accuracy 0.2906874450169662
# learning rate decay
# 20
# epoch 5 iteration 20 validation loss 2.1282068856557212 validation accuracy 0.2882996104059319
# learning rate decay
# 30
# epoch 5 iteration 30 validation loss 2.123018259684245 validation accuracy 0.2921955510870931
# current best accuracy: 0.2921955510870931
# learning rate decay
# 40
# epoch 5 iteration 40 validation loss 2.123812212308248 validation accuracy 0.29131582254618577
# learning rate decay
# 50
# epoch 5 iteration 50 validation loss 2.1177769673665363 validation accuracy 0.2884252859117758
# learning rate decay
# 60
# epoch 5 iteration 60 validation loss 2.1166993595759074 validation accuracy 0.29244690209878094
# current best accuracy: 0.29244690209878094
# learning rate decay
# 70
# epoch 5 iteration 70 validation loss 2.118211353937785 validation accuracy 0.2905617695111223
# learning rate decay
# 80
# epoch 5 iteration 80 validation loss 2.1216915070215863 validation accuracy 0.2915671735578736
# learning rate decay
# 90
# epoch 5 iteration 90 validation loss 2.114188477198283 validation accuracy 0.29332663063968833
# current best accuracy: 0.29332663063968833
# learning rate decay
# 100
# epoch 5 iteration 100 validation loss 2.1126799319585166 validation accuracy 0.29269825311046876
# learning rate decay
# 110
# epoch 5 iteration 110 validation loss 2.111993980407715 validation accuracy 0.2930752796280005
# learning rate decay
# 120
# epoch 5 iteration 120 validation loss 2.111024670283 validation accuracy 0.2950860877215031
# current best accuracy: 0.2950860877215031
# learning rate decay
# 130
# epoch 5 iteration 130 validation loss 2.1160962845484415 validation accuracy 0.29584014075656656
# current best accuracy: 0.29584014075656656
# learning rate decay
# 140
# epoch 5 iteration 140 validation loss 2.114977710088094 validation accuracy 0.295211763227347
# learning rate decay
# 150
# epoch 5 iteration 150 validation loss 2.1142038507461547 validation accuracy 0.2914414980520297
# learning rate decay
# 160
# epoch 5 iteration 160 validation loss 2.114766965866089 validation accuracy 0.2928239286163127
# learning rate decay
# 170
# epoch 5 iteration 170 validation loss 2.1105557260513303 validation accuracy 0.2944577101922835
# learning rate decay
# 180
# epoch 5 iteration 180 validation loss 2.111805444399516 validation accuracy 0.29257257760462485
# learning rate decay
# 0
# epoch 6 iteration 0 validation loss 2.1093535197575886 validation accuracy 0.29345230614553225
# learning rate decay
# 10
# epoch 6 iteration 10 validation loss 2.112141449292501 validation accuracy 0.2942063591805957
# learning rate decay
# 20
# epoch 6 iteration 20 validation loss 2.1116572818756105 validation accuracy 0.2914414980520297
# learning rate decay
# 30
# epoch 6 iteration 30 validation loss 2.107702701886495 validation accuracy 0.2944577101922835
# learning rate decay
# 40
# epoch 6 iteration 40 validation loss 2.107530912399292 validation accuracy 0.2930752796280005
# learning rate decay
# 50
# epoch 6 iteration 50 validation loss 2.102052660624186 validation accuracy 0.2929496041221566
# learning rate decay
# 60
# epoch 6 iteration 60 validation loss 2.103321276664734 validation accuracy 0.2950860877215031
# learning rate decay
# 70
# epoch 6 iteration 70 validation loss 2.106792690594991 validation accuracy 0.2930752796280005
# learning rate decay
# 80
# epoch 6 iteration 80 validation loss 2.1072879384358725 validation accuracy 0.2964685182857861
# current best accuracy: 0.2964685182857861
# learning rate decay
# 90
# epoch 6 iteration 90 validation loss 2.1001102867126464 validation accuracy 0.2964685182857861
# learning rate decay
# 100
# epoch 6 iteration 100 validation loss 2.0990435228347777 validation accuracy 0.2964685182857861
# learning rate decay
# 110
# epoch 6 iteration 110 validation loss 2.099826331138611 validation accuracy 0.2967198692974739
# current best accuracy: 0.2967198692974739
# learning rate decay
# 120
# epoch 6 iteration 120 validation loss 2.095441295305888 validation accuracy 0.29659419379163
# learning rate decay
# 130
# epoch 6 iteration 130 validation loss 2.098992061297099 validation accuracy 0.2959658162624105
# learning rate decay
# 140
# epoch 6 iteration 140 validation loss 2.1023553924560545 validation accuracy 0.29470906120397133
# learning rate decay
# 150
# epoch 6 iteration 150 validation loss 2.1018735405604043 validation accuracy 0.2914414980520297
# learning rate decay
# 160
# epoch 6 iteration 160 validation loss 2.1023113794326784 validation accuracy 0.29470906120397133
# learning rate decay
# 170
# epoch 6 iteration 170 validation loss 2.093220449765523 validation accuracy 0.2954631142390348
# learning rate decay
# 180
# epoch 6 iteration 180 validation loss 2.0940442771911623 validation accuracy 0.2919442000754053
# learning rate decay
# 0
# epoch 7 iteration 0 validation loss 2.0927847099304198 validation accuracy 0.2962171672740983
# learning rate decay
# 10
# epoch 7 iteration 10 validation loss 2.088350083351135 validation accuracy 0.2967198692974739
# learning rate decay
# 20
# epoch 7 iteration 20 validation loss 2.0887290188471477 validation accuracy 0.29496041221565916
# learning rate decay
# 30
# epoch 7 iteration 30 validation loss 2.0881455624898275 validation accuracy 0.2959658162624105
# learning rate decay
# 40
# epoch 7 iteration 40 validation loss 2.0874657046000165 validation accuracy 0.2943320346864396
# learning rate decay
# 50
# epoch 7 iteration 50 validation loss 2.083104147275289 validation accuracy 0.2939550081689079
# learning rate decay
# 60
# epoch 7 iteration 60 validation loss 2.082705291748047 validation accuracy 0.2964685182857861
# learning rate decay
# 70
# epoch 7 iteration 70 validation loss 2.082549406369527 validation accuracy 0.2991077039085082
# current best accuracy: 0.2991077039085082
# learning rate decay
# 80
# epoch 7 iteration 80 validation loss 2.080679549853007 validation accuracy 0.2988563528968204
# learning rate decay
# 90
# epoch 7 iteration 90 validation loss 2.078510892868042 validation accuracy 0.2983536508734448
# learning rate decay
# 100
# epoch 7 iteration 100 validation loss 2.077666671117147 validation accuracy 0.2991077039085082
# learning rate decay
# 110
# epoch 7 iteration 110 validation loss 2.0754228048324586 validation accuracy 0.2987306773909765
# learning rate decay
# 120
# epoch 7 iteration 120 validation loss 2.0759433380762737 validation accuracy 0.29785094885006913
# learning rate decay
# 130
# epoch 7 iteration 130 validation loss 2.0802497351964315 validation accuracy 0.2973482468266935
# learning rate decay
# 140
# epoch 7 iteration 140 validation loss 2.0795261818567914 validation accuracy 0.2967198692974739
# learning rate decay
# 150
# epoch 7 iteration 150 validation loss 2.0783656600316367 validation accuracy 0.29558878974487873
# learning rate decay
# 160
# epoch 7 iteration 160 validation loss 2.078582597732544 validation accuracy 0.2962171672740983
# learning rate decay
# 170
# epoch 7 iteration 170 validation loss 2.074691146214803 validation accuracy 0.29584014075656656
# learning rate decay
# 180
# epoch 7 iteration 180 validation loss 2.0779534085591633 validation accuracy 0.2953374387331909
# learning rate decay
# 0
# epoch 8 iteration 0 validation loss 2.0758393494288128 validation accuracy 0.2983536508734448
# learning rate decay
# 10
# epoch 8 iteration 10 validation loss 2.0743004760742187 validation accuracy 0.2989820284026643
# learning rate decay
# 20
# epoch 8 iteration 20 validation loss 2.071790113449097 validation accuracy 0.2960914917682544
# learning rate decay
# 30
# epoch 8 iteration 30 validation loss 2.0700169143676757 validation accuracy 0.2973482468266935
# learning rate decay
# 40
# epoch 8 iteration 40 validation loss 2.0725312080383302 validation accuracy 0.2967198692974739
# learning rate decay
# 50
# epoch 8 iteration 50 validation loss 2.064310722668966 validation accuracy 0.29571446525072265
# learning rate decay
# 60
# epoch 8 iteration 60 validation loss 2.0642709538141886 validation accuracy 0.2991077039085082
# learning rate decay
# 70
# epoch 8 iteration 70 validation loss 2.0668121910095216 validation accuracy 0.2987306773909765
# learning rate decay
# 80
# epoch 8 iteration 80 validation loss 2.064632963180542 validation accuracy 0.2999874324494156
# current best accuracy: 0.2999874324494156
# learning rate decay
# 90
# epoch 8 iteration 90 validation loss 2.0605714740753176 validation accuracy 0.29961040593188387
# best model, val loss:  2.0605714740753176 best model,validation accuracy: 0.29961040593188387
# 100
# epoch 8 iteration 100 validation loss 2.062581120491028 validation accuracy 0.30174688953123036
# current best accuracy: 0.30174688953123036
# learning rate decay
# 110
# epoch 8 iteration 110 validation loss 2.058758595466614 validation accuracy 0.29961040593188387
# best model, val loss:  2.058758595466614 best model,validation accuracy: 0.29961040593188387
# 120
# epoch 8 iteration 120 validation loss 2.0509989891052247 validation accuracy 0.29923337941435213
# best model, val loss:  2.0509989891052247 best model,validation accuracy: 0.29923337941435213
# 130
# epoch 8 iteration 130 validation loss 2.047139470418294 validation accuracy 0.30174688953123036
# best model, val loss:  2.047139470418294 best model,validation accuracy: 0.30174688953123036
# 140
# epoch 8 iteration 140 validation loss 2.038506302515666 validation accuracy 0.3007414854844791
# best model, val loss:  2.038506302515666 best model,validation accuracy: 0.3007414854844791
# 150
# epoch 8 iteration 150 validation loss 2.034768288930257 validation accuracy 0.30049013447279127
# best model, val loss:  2.034768288930257 best model,validation accuracy: 0.30049013447279127
# 160
# epoch 8 iteration 160 validation loss 2.0292481463750205 validation accuracy 0.2998617569435717
# best model, val loss:  2.0292481463750205 best model,validation accuracy: 0.2998617569435717
# 170
# epoch 8 iteration 170 validation loss 2.021360062281291 validation accuracy 0.30174688953123036
# best model, val loss:  2.021360062281291 best model,validation accuracy: 0.30174688953123036
# 180
# epoch 8 iteration 180 validation loss 2.0156156702041628 validation accuracy 0.30011310795525953
# best model, val loss:  2.0156156702041628 best model,validation accuracy: 0.30011310795525953
# 0
# epoch 9 iteration 0 validation loss 2.013823785463969 validation accuracy 0.3012441875078547
# best model, val loss:  2.013823785463969 best model,validation accuracy: 0.3012441875078547
# 10
# epoch 9 iteration 10 validation loss 2.009511898994446 validation accuracy 0.300867160990323
# best model, val loss:  2.009511898994446 best model,validation accuracy: 0.300867160990323
# 20
# epoch 9 iteration 20 validation loss 2.0029217354456583 validation accuracy 0.3021239160487621
# current best accuracy: 0.3021239160487621
# best model, val loss:  2.0029217354456583 best model,validation accuracy: 0.3021239160487621
# 30
# epoch 9 iteration 30 validation loss 1.9970295063654582 validation accuracy 0.302249591554606
# current best accuracy: 0.302249591554606
# best model, val loss:  1.9970295063654582 best model,validation accuracy: 0.302249591554606
# 40
# epoch 9 iteration 40 validation loss 1.9926031907399495 validation accuracy 0.30325499560135727
# current best accuracy: 0.30325499560135727
# best model, val loss:  1.9926031907399495 best model,validation accuracy: 0.30325499560135727
# 50
# epoch 9 iteration 50 validation loss 1.9910400565465292 validation accuracy 0.3019982405429182
# best model, val loss:  1.9910400565465292 best model,validation accuracy: 0.3019982405429182
# 60
# epoch 9 iteration 60 validation loss 1.9840376205444337 validation accuracy 0.30162121402538644
# best model, val loss:  1.9840376205444337 best model,validation accuracy: 0.30162121402538644
# 70
# epoch 9 iteration 70 validation loss 1.9842664464314779 validation accuracy 0.3030036445896695
# learning rate decay
# 80
# epoch 9 iteration 80 validation loss 1.9919695342381796 validation accuracy 0.3033806711072012
# current best accuracy: 0.3033806711072012
# learning rate decay
# 90
# epoch 9 iteration 90 validation loss 1.9867491184870403 validation accuracy 0.3046374261656403
# current best accuracy: 0.3046374261656403
# learning rate decay
# 100
# epoch 9 iteration 100 validation loss 1.9896816161473592 validation accuracy 0.3056428302123916
# current best accuracy: 0.3056428302123916
# learning rate decay
# 110
# epoch 9 iteration 110 validation loss 1.992299147605896 validation accuracy 0.3057685057182355
# current best accuracy: 0.3057685057182355
# learning rate decay
# 120
# epoch 9 iteration 120 validation loss 1.9911552562713624 validation accuracy 0.3075279628000503
# current best accuracy: 0.3075279628000503
# learning rate decay
# 130
# epoch 9 iteration 130 validation loss 1.9990040070215862 validation accuracy 0.305140128189016
# learning rate decay
# 140
# epoch 9 iteration 140 validation loss 2.0000960321426393 validation accuracy 0.3042603996481086
# learning rate decay
# 150
# epoch 9 iteration 150 validation loss 2.0023656463623047 validation accuracy 0.3067739097649868
# learning rate decay
# 160
# epoch 9 iteration 160 validation loss 2.00918883005778 validation accuracy 0.30388337313057684
# learning rate decay
# 170
# epoch 9 iteration 170 validation loss 2.0028400831222535 validation accuracy 0.3056428302123916
# learning rate decay
# 180
# epoch 9 iteration 180 validation loss 2.0089211603800456 validation accuracy 0.3019982405429182
# learning rate decay
# 0
# epoch 10 iteration 0 validation loss 2.007385293006897 validation accuracy 0.30476310167148424
# learning rate decay
# 10
# epoch 10 iteration 10 validation loss 2.005489073753357 validation accuracy 0.3057685057182355
# learning rate decay
# 20
# epoch 10 iteration 20 validation loss 2.0113901974360147 validation accuracy 0.3043860751539525
# learning rate decay
# 30
# epoch 10 iteration 30 validation loss 2.0097602157592775 validation accuracy 0.30325499560135727
# learning rate decay
# 40
# epoch 10 iteration 40 validation loss 2.0127895650863645 validation accuracy 0.3033806711072012
# learning rate decay
# 50
# epoch 10 iteration 50 validation loss 2.0105097068150837 validation accuracy 0.3031293200955134
# learning rate decay
# 60
# epoch 10 iteration 60 validation loss 2.0083048276901243 validation accuracy 0.3060198567299233
# learning rate decay
# 70
# epoch 10 iteration 70 validation loss 2.008906964619954 validation accuracy 0.30501445268317207
# learning rate decay
# 80
# epoch 10 iteration 80 validation loss 2.011886348406474 validation accuracy 0.3057685057182355
# learning rate decay
# 90
# epoch 10 iteration 90 validation loss 2.0070045811335246 validation accuracy 0.3058941812240794
# learning rate decay
# 100
# epoch 10 iteration 100 validation loss 2.0123375040690106 validation accuracy 0.3066482342591429
# learning rate decay
# 110
# epoch 10 iteration 110 validation loss 2.0110110330581663 validation accuracy 0.3075279628000503
# learning rate decay
# 120
# epoch 10 iteration 120 validation loss 2.010002255121867 validation accuracy 0.3089103933643333
# current best accuracy: 0.3089103933643333
# learning rate decay
# 130
# epoch 10 iteration 130 validation loss 2.010523038228353 validation accuracy 0.30551715470654767
# learning rate decay
# 140
# epoch 10 iteration 140 validation loss 2.0131945985158284 validation accuracy 0.30501445268317207
# learning rate decay
# 150
# epoch 10 iteration 150 validation loss 2.012646416982015 validation accuracy 0.3067739097649868
# learning rate decay
# 160
# epoch 10 iteration 160 validation loss 2.015013437271118 validation accuracy 0.30614553223576724
# learning rate decay
# 170
# epoch 10 iteration 170 validation loss 2.0105706179936726 validation accuracy 0.30614553223576724
# learning rate decay
# 180
# epoch 10 iteration 180 validation loss 2.0106084785461427 validation accuracy 0.30627120774161115
# learning rate decay
# 0
# epoch 11 iteration 0 validation loss 2.0134033250808714 validation accuracy 0.305140128189016
# learning rate decay
# 10
# epoch 11 iteration 10 validation loss 2.014622940381368 validation accuracy 0.3060198567299233
# learning rate decay
# 20
# epoch 11 iteration 20 validation loss 2.0146360909144083 validation accuracy 0.30702526077667464
# learning rate decay
# 30
# epoch 11 iteration 30 validation loss 2.0169703760147093 validation accuracy 0.30627120774161115
# learning rate decay
# 40
# epoch 11 iteration 40 validation loss 2.017033605893453 validation accuracy 0.306522558753299
# learning rate decay
# 50
# epoch 11 iteration 50 validation loss 2.0092461468378704 validation accuracy 0.30488877717732815
# learning rate decay
# 60
# epoch 11 iteration 60 validation loss 2.0074381841023765 validation accuracy 0.306522558753299
# learning rate decay
# 70
# epoch 11 iteration 70 validation loss 2.0066637681325274 validation accuracy 0.3081563403292698
# learning rate decay
# 80
# epoch 11 iteration 80 validation loss 2.012116118748983 validation accuracy 0.30614553223576724
# learning rate decay
# 90
# epoch 11 iteration 90 validation loss 2.009288142522176 validation accuracy 0.3075279628000503
# learning rate decay
# 100
# epoch 11 iteration 100 validation loss 2.011197509129842 validation accuracy 0.3075279628000503
# learning rate decay
# 110
# epoch 11 iteration 110 validation loss 2.0142846037546795 validation accuracy 0.3066482342591429
# learning rate decay
# 120
# epoch 11 iteration 120 validation loss 2.0073742605845135 validation accuracy 0.30727661178836246
# learning rate decay
# 130
# epoch 11 iteration 130 validation loss 2.010825809160868 validation accuracy 0.3075279628000503
# learning rate decay
# 140
# epoch 11 iteration 140 validation loss 2.0169958658218383 validation accuracy 0.30614553223576724
# learning rate decay
# 150
# epoch 11 iteration 150 validation loss 2.0133987655639647 validation accuracy 0.3081563403292698
# learning rate decay
# 160
# epoch 11 iteration 160 validation loss 2.01175910059611 validation accuracy 0.3060198567299233
# learning rate decay
# 170
# epoch 11 iteration 170 validation loss 2.0058132858276365 validation accuracy 0.3090360688701772
# current best accuracy: 0.3090360688701772
# learning rate decay
# 180
# epoch 11 iteration 180 validation loss 2.0062626647949218 validation accuracy 0.3074022872942064
# learning rate decay
# 0
# epoch 12 iteration 0 validation loss 2.009341547648112 validation accuracy 0.30840769134095763
# learning rate decay
# 10
# epoch 12 iteration 10 validation loss 2.0160418469111123 validation accuracy 0.3089103933643333
# learning rate decay
# 20
# epoch 12 iteration 20 validation loss 2.011955216407776 validation accuracy 0.30715093628251855
# learning rate decay
# 30
# epoch 12 iteration 30 validation loss 2.0110011784235637 validation accuracy 0.30627120774161115
# learning rate decay
# 40
# epoch 12 iteration 40 validation loss 2.0100486981074015 validation accuracy 0.3087847178584894
# learning rate decay
# 50
# epoch 12 iteration 50 validation loss 2.0080175619125367 validation accuracy 0.3080306648234259
# learning rate decay
# 60
# epoch 12 iteration 60 validation loss 2.0074774707158407 validation accuracy 0.30941309538770895
# current best accuracy: 0.30941309538770895
# learning rate decay
# 70
# epoch 12 iteration 70 validation loss 2.0070879042943317 validation accuracy 0.30853336684680155
# learning rate decay
# 80
# epoch 12 iteration 80 validation loss 2.0101926530202228 validation accuracy 0.3075279628000503
# learning rate decay
# 90
# epoch 12 iteration 90 validation loss 2.009800495147705 validation accuracy 0.30953877089355286
# current best accuracy: 0.30953877089355286
# learning rate decay
# 100
# epoch 12 iteration 100 validation loss 2.0164533818562824 validation accuracy 0.3082820158351137
# learning rate decay
# 110
# epoch 12 iteration 110 validation loss 2.009719751040141 validation accuracy 0.30840769134095763
# learning rate decay
# 120
# epoch 12 iteration 120 validation loss 2.005479556719462 validation accuracy 0.30840769134095763
# learning rate decay
# 130
# epoch 12 iteration 130 validation loss 2.0120946807861326 validation accuracy 0.3089103933643333
# learning rate decay
# 140
# epoch 12 iteration 140 validation loss 2.0128720423380533 validation accuracy 0.3076536383058942
# learning rate decay
# 150
# epoch 12 iteration 150 validation loss 2.011166727701823 validation accuracy 0.30953877089355286
# learning rate decay
# 160
# epoch 12 iteration 160 validation loss 2.0118858369191486 validation accuracy 0.30928741988186503
# learning rate decay
# 170
# epoch 12 iteration 170 validation loss 2.0093330113093057 validation accuracy 0.30928741988186503
# learning rate decay
# 180
# epoch 12 iteration 180 validation loss 2.0089720493952434 validation accuracy 0.30853336684680155
# learning rate decay
# 0
# epoch 13 iteration 0 validation loss 2.0167587280273436 validation accuracy 0.3105441749403041
# current best accuracy: 0.3105441749403041
# learning rate decay
# 10
# epoch 13 iteration 10 validation loss 2.009920580546061 validation accuracy 0.312177956516275
# current best accuracy: 0.312177956516275
# learning rate decay
# 20
# epoch 13 iteration 20 validation loss 2.013615576108297 validation accuracy 0.3110468769636798
# learning rate decay
# 30
# epoch 13 iteration 30 validation loss 2.012153575261434 validation accuracy 0.3111725524695237
# learning rate decay
# 40
# epoch 13 iteration 40 validation loss 2.0128058818181356 validation accuracy 0.30941309538770895
# learning rate decay
# 50
# epoch 13 iteration 50 validation loss 2.0092004550298057 validation accuracy 0.3080306648234259
# learning rate decay
# 60
# epoch 13 iteration 60 validation loss 2.0102125180562336 validation accuracy 0.3110468769636798
# learning rate decay
# 70
# epoch 13 iteration 70 validation loss 2.0140617742538454 validation accuracy 0.3120522810104311
# learning rate decay
# 80
# epoch 13 iteration 80 validation loss 2.010267911275228 validation accuracy 0.31180092999874326
# learning rate decay
# 90
# epoch 13 iteration 90 validation loss 2.010639705657959 validation accuracy 0.3114239034812115
# learning rate decay
# 100
# epoch 13 iteration 100 validation loss 2.0135960909525554 validation accuracy 0.3126806585396506
# current best accuracy: 0.3126806585396506
# learning rate decay
# 110
# epoch 13 iteration 110 validation loss 2.0118888190587363 validation accuracy 0.31154957898705543
# learning rate decay
# 120
# epoch 13 iteration 120 validation loss 2.012568181673686 validation accuracy 0.3105441749403041
# learning rate decay
# 130
# epoch 13 iteration 130 validation loss 2.0123867816925047 validation accuracy 0.31066985044614803
# learning rate decay
# 140
# epoch 13 iteration 140 validation loss 2.01393080997467 validation accuracy 0.31154957898705543
# learning rate decay
# 150
# epoch 13 iteration 150 validation loss 2.0169717721939087 validation accuracy 0.3100414729169285
# learning rate decay
# 160
# epoch 13 iteration 160 validation loss 2.020049574216207 validation accuracy 0.3104184994344602
# learning rate decay
# 170
# epoch 13 iteration 170 validation loss 2.0120541451772054 validation accuracy 0.3112982279753676
# learning rate decay
# 180
# epoch 13 iteration 180 validation loss 2.0099793345133463 validation accuracy 0.31079552595199195
# learning rate decay
# 0
# epoch 14 iteration 0 validation loss 2.0133087571461994 validation accuracy 0.31180092999874326
# learning rate decay
# 10
# epoch 14 iteration 10 validation loss 2.0154302158355715 validation accuracy 0.31154957898705543
# learning rate decay
# 20
# epoch 14 iteration 20 validation loss 2.014765540122986 validation accuracy 0.3112982279753676
# learning rate decay
# 30
# epoch 14 iteration 30 validation loss 2.0129396832784017 validation accuracy 0.3104184994344602
# learning rate decay
# 40
# epoch 14 iteration 40 validation loss 2.014930048942566 validation accuracy 0.3112982279753676
# learning rate decay
# 50
# epoch 14 iteration 50 validation loss 2.0115124216079714 validation accuracy 0.3067739097649868
# learning rate decay
# 60
# epoch 14 iteration 60 validation loss 2.010005167643229 validation accuracy 0.31092120145783586
# learning rate decay
# 70
# epoch 14 iteration 70 validation loss 2.010995157877604 validation accuracy 0.31092120145783586
# learning rate decay
# 80
# epoch 14 iteration 80 validation loss 2.011909506479899 validation accuracy 0.3099157974110846
# learning rate decay
# 90
# epoch 14 iteration 90 validation loss 2.009934994061788 validation accuracy 0.3134347115747141
# current best accuracy: 0.3134347115747141
# learning rate decay
# 100
# epoch 14 iteration 100 validation loss 2.013135803222656 validation accuracy 0.31406308910393366
# current best accuracy: 0.31406308910393366
# learning rate decay
# 110
# epoch 14 iteration 110 validation loss 2.0095846325556437 validation accuracy 0.31393741359808974
# learning rate decay
# 120
# epoch 14 iteration 120 validation loss 2.0072039887110393 validation accuracy 0.3124293075279628
# learning rate decay
# 130
# epoch 14 iteration 130 validation loss 2.0083312203089396 validation accuracy 0.3136860625864019
# learning rate decay
# 140
# epoch 14 iteration 140 validation loss 2.008963668187459 validation accuracy 0.3114239034812115
# learning rate decay
# 150
# epoch 14 iteration 150 validation loss 2.0111738319396975 validation accuracy 0.3134347115747141
# learning rate decay
# 160
# epoch 14 iteration 160 validation loss 2.010311236699422 validation accuracy 0.312177956516275
# learning rate decay
# 170
# epoch 14 iteration 170 validation loss 2.0099608481725055 validation accuracy 0.3144401156214654
# current best accuracy: 0.3144401156214654
# learning rate decay
# 180
# epoch 14 iteration 180 validation loss 2.0077785024642942 validation accuracy 0.3136860625864019
# learning rate decay
# 0
# epoch 15 iteration 0 validation loss 2.008829926808675 validation accuracy 0.3136860625864019
# learning rate decay
# 10
# epoch 15 iteration 10 validation loss 2.01196342754364 validation accuracy 0.3136860625864019
# learning rate decay
# 20
# epoch 15 iteration 20 validation loss 2.008786032040914 validation accuracy 0.3119266055045872
# learning rate decay
# 30
# epoch 15 iteration 30 validation loss 2.0110678017934163 validation accuracy 0.3123036320221189
# learning rate decay
# 40
# epoch 15 iteration 40 validation loss 2.009077947616577 validation accuracy 0.3125549830338067
# learning rate decay
# 50
# epoch 15 iteration 50 validation loss 2.0094929157892865 validation accuracy 0.3076536383058942
# learning rate decay
# 60
# epoch 15 iteration 60 validation loss 2.0084905246098836 validation accuracy 0.30953877089355286
# learning rate decay
# 70
# epoch 15 iteration 70 validation loss 2.0053163312276205 validation accuracy 0.3124293075279628
# learning rate decay
# 80
# epoch 15 iteration 80 validation loss 2.008909005800883 validation accuracy 0.3133090360688702
# learning rate decay
# 90
# epoch 15 iteration 90 validation loss 2.0071346311569216 validation accuracy 0.31519416865652883
# current best accuracy: 0.31519416865652883
# learning rate decay
# 100
# epoch 15 iteration 100 validation loss 2.0074737288157145 validation accuracy 0.31619957270328014
# current best accuracy: 0.31619957270328014
# learning rate decay
# 110
# epoch 15 iteration 110 validation loss 2.0034087632497153 validation accuracy 0.31619957270328014
# learning rate decay
# 120
# epoch 15 iteration 120 validation loss 2.0032006810506187 validation accuracy 0.31557119517406057
# learning rate decay
# 130
# epoch 15 iteration 130 validation loss 2.00350194422404 validation accuracy 0.313560387080558
# learning rate decay
# 140
# epoch 15 iteration 140 validation loss 2.0074247652689614 validation accuracy 0.31531984416237274
# learning rate decay
# 150
# epoch 15 iteration 150 validation loss 2.0040790433883666 validation accuracy 0.313560387080558
# learning rate decay
# 160
# epoch 15 iteration 160 validation loss 2.0115503997802735 validation accuracy 0.31406308910393366
# learning rate decay
# 170
# epoch 15 iteration 170 validation loss 2.0023557103474934 validation accuracy 0.31531984416237274
# learning rate decay
# 180
# epoch 15 iteration 180 validation loss 2.0047193053563435 validation accuracy 0.31418876460977757
# learning rate decay
# 0
# epoch 16 iteration 0 validation loss 2.008506165822347 validation accuracy 0.31544551966821666
# learning rate decay
# 10
# epoch 16 iteration 10 validation loss 2.01016641330719 validation accuracy 0.3148171421389971
# learning rate decay
# 20
# epoch 16 iteration 20 validation loss 2.006142604192098 validation accuracy 0.3148171421389971
# learning rate decay
# 30
# epoch 16 iteration 30 validation loss 2.003184997876485 validation accuracy 0.31531984416237274
# learning rate decay
# 40
# epoch 16 iteration 40 validation loss 2.009434048016866 validation accuracy 0.31418876460977757
# learning rate decay
# 50
# epoch 16 iteration 50 validation loss 2.003078150113424 validation accuracy 0.3133090360688702
# learning rate decay
# 60
# epoch 16 iteration 60 validation loss 2.002064288457235 validation accuracy 0.3148171421389971
# learning rate decay
# 70
# epoch 16 iteration 70 validation loss 2.0006542673110963 validation accuracy 0.3172049767500314
# current best accuracy: 0.3172049767500314
# learning rate decay
# 80
# epoch 16 iteration 80 validation loss 2.002352664311727 validation accuracy 0.3156968706799045
# learning rate decay
# 90
# epoch 16 iteration 90 validation loss 2.0033740523656207 validation accuracy 0.31557119517406057
# learning rate decay
# 100
# epoch 16 iteration 100 validation loss 2.005322028160095 validation accuracy 0.31783335427925097
# current best accuracy: 0.31783335427925097
# learning rate decay
# 110
# epoch 16 iteration 110 validation loss 2.0030330209732057 validation accuracy 0.3173306522558753
# learning rate decay
# 120
# epoch 16 iteration 120 validation loss 1.9990953369140625 validation accuracy 0.3174563277617192
# learning rate decay
# 130
# epoch 16 iteration 130 validation loss 2.0011314582824706 validation accuracy 0.3148171421389971
# learning rate decay
# 140
# epoch 16 iteration 140 validation loss 2.001897516568502 validation accuracy 0.3143144401156215
# learning rate decay
# 150
# epoch 16 iteration 150 validation loss 2.0032380129496254 validation accuracy 0.3148171421389971
# learning rate decay
# 160
# epoch 16 iteration 160 validation loss 2.003782240867615 validation accuracy 0.31619957270328014
# learning rate decay
# 170
# epoch 16 iteration 170 validation loss 1.999617958386739 validation accuracy 0.3168279502324997
# learning rate decay
# 180
# epoch 16 iteration 180 validation loss 1.9997613445917766 validation accuracy 0.3159482216915923
# learning rate decay
# 0
# epoch 17 iteration 0 validation loss 2.0016567618052163 validation accuracy 0.3160738971974362
# learning rate decay
# 10
# epoch 17 iteration 10 validation loss 2.001047824859619 validation accuracy 0.31695362573834357
# learning rate decay
# 20
# epoch 17 iteration 20 validation loss 1.9998242321014403 validation accuracy 0.31544551966821666
# learning rate decay
# 30
# epoch 17 iteration 30 validation loss 2.0000596685409544 validation accuracy 0.31695362573834357
# learning rate decay
# 40
# epoch 17 iteration 40 validation loss 1.9995110432306926 validation accuracy 0.3144401156214654
# learning rate decay
# 50
# epoch 17 iteration 50 validation loss 2.0028084055582682 validation accuracy 0.31381173809224583
# learning rate decay
# 60
# epoch 17 iteration 60 validation loss 1.9949998610814412 validation accuracy 0.31544551966821666
# learning rate decay
# 70
# epoch 17 iteration 70 validation loss 1.9977954279581707 validation accuracy 0.3133090360688702
# learning rate decay
# 80
# epoch 17 iteration 80 validation loss 1.995781537691752 validation accuracy 0.3165765992208119
# learning rate decay
# 90
# epoch 17 iteration 90 validation loss 2.000112203915914 validation accuracy 0.3174563277617192
# learning rate decay
# 100
# epoch 17 iteration 100 validation loss 1.997360289255778 validation accuracy 0.3167022747266558
# learning rate decay
# 110
# epoch 17 iteration 110 validation loss 1.996583149909973 validation accuracy 0.3179590297850949
# current best accuracy: 0.3179590297850949
# learning rate decay
# 120
# epoch 17 iteration 120 validation loss 1.996620007832845 validation accuracy 0.31632524820912405
# learning rate decay
# 130
# epoch 17 iteration 130 validation loss 1.998155218442281 validation accuracy 0.3167022747266558
# learning rate decay
# 140
# epoch 17 iteration 140 validation loss 1.999252421061198 validation accuracy 0.3160738971974362
# learning rate decay
# 150
# epoch 17 iteration 150 validation loss 1.9977382949193319 validation accuracy 0.3167022747266558
# learning rate decay
# 160
# epoch 17 iteration 160 validation loss 1.999088121732076 validation accuracy 0.314942817644841
# learning rate decay
# 170
# epoch 17 iteration 170 validation loss 1.9981942246754965 validation accuracy 0.31783335427925097
# learning rate decay
# 180
# epoch 17 iteration 180 validation loss 1.9934902772903442 validation accuracy 0.31770767877340705
# learning rate decay
# 0
# epoch 18 iteration 0 validation loss 2.0004197991689048 validation accuracy 0.3179590297850949
# learning rate decay
# 10
# epoch 18 iteration 10 validation loss 2.00114156182607 validation accuracy 0.31544551966821666
# learning rate decay
# 20
# epoch 18 iteration 20 validation loss 1.997252581914266 validation accuracy 0.3170793012441875
# learning rate decay
# 30
# epoch 18 iteration 30 validation loss 1.9989609368642172 validation accuracy 0.31783335427925097
# learning rate decay
# 40
# epoch 18 iteration 40 validation loss 1.9969448455174763 validation accuracy 0.3168279502324997
# learning rate decay
# 50
# epoch 18 iteration 50 validation loss 1.9999619124730428 validation accuracy 0.31167525449289935
# learning rate decay
# 60
# epoch 18 iteration 60 validation loss 1.9964481662114462 validation accuracy 0.31645092371496797
# learning rate decay
# 70
# epoch 18 iteration 70 validation loss 1.996093999226888 validation accuracy 0.31544551966821666
# learning rate decay
# 80
# epoch 18 iteration 80 validation loss 1.9995293731689454 validation accuracy 0.31544551966821666
# learning rate decay
# 90
# epoch 18 iteration 90 validation loss 2.000073499361674 validation accuracy 0.31531984416237274
# learning rate decay
# 100
# epoch 18 iteration 100 validation loss 1.997627729733785 validation accuracy 0.3180847052909388
# current best accuracy: 0.3180847052909388
# learning rate decay
# 110
# epoch 18 iteration 110 validation loss 1.9958687550226848 validation accuracy 0.31758200326756314
# learning rate decay
# 120
# epoch 18 iteration 120 validation loss 1.9930143706003824 validation accuracy 0.3173306522558753
# learning rate decay
# 130
# epoch 18 iteration 130 validation loss 1.9954601955413818 validation accuracy 0.3144401156214654
# learning rate decay
# 140
# epoch 18 iteration 140 validation loss 1.9973271137873332 validation accuracy 0.31632524820912405
# learning rate decay
# 150
# epoch 18 iteration 150 validation loss 1.996253745396932 validation accuracy 0.3156968706799045
# learning rate decay
# 160
# epoch 18 iteration 160 validation loss 1.9995447107950846 validation accuracy 0.3150684931506849
# learning rate decay
# 170
# epoch 18 iteration 170 validation loss 1.9978757263819376 validation accuracy 0.3160738971974362
# learning rate decay
# 180
# epoch 18 iteration 180 validation loss 1.994156984647115 validation accuracy 0.3173306522558753
# learning rate decay
# 0
# epoch 19 iteration 0 validation loss 1.9999547723134359 validation accuracy 0.31783335427925097
# learning rate decay
# 10
# epoch 19 iteration 10 validation loss 2.002728485107422 validation accuracy 0.3170793012441875
# learning rate decay
# 20
# epoch 19 iteration 20 validation loss 1.9954069763819378 validation accuracy 0.3160738971974362
# learning rate decay
# 30
# epoch 19 iteration 30 validation loss 1.9971992073059082 validation accuracy 0.31531984416237274
# learning rate decay
# 40
# epoch 19 iteration 40 validation loss 1.9993711595535277 validation accuracy 0.31544551966821666
# learning rate decay
# 50
# epoch 19 iteration 50 validation loss 2.001457802136739 validation accuracy 0.31557119517406057
# learning rate decay
# 60
# epoch 19 iteration 60 validation loss 1.9982657772699992 validation accuracy 0.3160738971974362
# learning rate decay
# 70
# epoch 19 iteration 70 validation loss 1.9976070845921834 validation accuracy 0.3168279502324997
# learning rate decay
# 80
# epoch 19 iteration 80 validation loss 1.996973269780477 validation accuracy 0.3172049767500314
# learning rate decay
# 90
# epoch 19 iteration 90 validation loss 1.997040524482727 validation accuracy 0.3182103807967827
# current best accuracy: 0.3182103807967827
# learning rate decay
# 100
# epoch 19 iteration 100 validation loss 1.9953009510040283 validation accuracy 0.3170793012441875
# learning rate decay
# 110
# epoch 19 iteration 110 validation loss 1.993706840833028 validation accuracy 0.3172049767500314
# learning rate decay
# 120
# epoch 19 iteration 120 validation loss 1.9963167012532552 validation accuracy 0.31632524820912405
# learning rate decay
# 130
# epoch 19 iteration 130 validation loss 1.9961128835678101 validation accuracy 0.31619957270328014
# learning rate decay
# 140
# epoch 19 iteration 140 validation loss 2.0006375013987223 validation accuracy 0.31695362573834357
# learning rate decay
# 150
# epoch 19 iteration 150 validation loss 1.9970741306940714 validation accuracy 0.3159482216915923
# learning rate decay
# 160
# epoch 19 iteration 160 validation loss 1.9981751832962036 validation accuracy 0.31645092371496797
# learning rate decay
# 170
# epoch 19 iteration 170 validation loss 1.9950168533325194 validation accuracy 0.3158225461857484
# learning rate decay
# 180
# epoch 19 iteration 180 validation loss 1.9944103088378906 validation accuracy 0.3167022747266558
# learning rate decay

# %%
print(max(val_best_acc))
# Out:
# 0.3182103807967827

# %%
# 加载保存好的模型参数
best_model = LSTMModel(vocab_size = VOCAB_SZIE,embed_size = EMBEDDING_SIZE, hidden_size = HIDDEN_SIZE,n_layers=N_LAYERS,dropout=0.5)
if USE_CUDA:
    best_model = best_model.to(device)
best_model.load_state_dict(torch.load("lm.pth"))
# 把模型参数load到best_model里
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
test_loss,test_acc,test_pre_tar = evaluate(best_model,test_dataloader)
print(val_acc)
# Out:
# 0.3167022747266558

# %%
print(test_pre_tar)#（错误词，真实值）
# Out:
# [[('He', 'Sue'), ('was', 'stuck'), ('a', 'with'), ('the', 'dance'), ('was', 'loved'), ('the', 'it'), ('He', 'It'), ('was', 'just'), ('his', 'opened'), ('a', 'up'), ('and', 'around'), ('store', 'corner'), ('He', 'Tina'), ('was', 'saw'), ('the', 'Sue'), ('was', ','), ('she', 'and'), ('was', 'invited'), ('go', 'sit'), ('.', 'at'), ('the', 'her'), ('.', 'table'), ('He', 'She'), ('was', 'realized'), ('she', 'they'), ('was', 'didn'), ('a', 'her'), ('friends', 'size'), ('.', 'so'), ('he', 'she'), ('was', 'left'), ('the', 'with'), ('the', 'no'), ('.', 'sweater'), ('was', 'noticed'), ('that', 'there'), ('was', 'wasn'), ('want', 'much'), ('a', '.'), ('He', 'Bob'), ('was', "'s"), ('was', 'said'), ('she', 'he'), ('was', 'could'), ('not', 'only'), ('go', 'have'), ('a', 'pizza'), ('.', 'if'), ('was', 'cleaned'), ('.', 'his'), ('house', 'room'), ('He', 'She'), ('was', 'got'), ('a', 'out'), ('and', 'of'), ('the', 'bed'), ('.', 'to'), ('the', 'go'), ('to', 'see'), ('.', 'what'), ('he', 'it'), ('very', '.'), ('He', 'His'), ('mother', 'mom'), ('was', 'and'), ("'t", 'dad'), ('to', 'told'), ('her', 'him'), ('to', 'that'), ('he', 'soon'), ('was', 'he'), ('was', 'would'), ('have', 'be'), ('.', 'a'), ('new', 'big'), ('.', 'brother'), ('He', 'When'), ('got', 'brought'), ('her', 'him'), (',', 'home'), ('Bob', 'she'), ('was', 'realized'), ('she', 'something'), ('was', '.'), ('He', 'Bob'), ('was', 'came'), ('to', 'home'), ('went', 'played'), ('.', 'football'), ('the', 'for'), ('the', 'a'), ('store', 'community'), ('.', 'college'), ('He', 'At'), ('day', 'the'), ('day', 'dentist'), ('was', 'learned'), ('to', 'he'), ('was', 'had'), ('lot', 'bad'), ('.', 'tooth'), ('He', 'Now'), ('she', 'he'), ('was', 'would'), ('not', 'be'), ('a', 'able'), ('go', 'see'), ('new', 'world'), ('.', '!'), ('He', 'She'), ('was', 'needed'), ('go', 'find'), ('a', 'her'), ('friends', 'keys'), ('.', 'in'), ('the', 'her'), ('store', 'purse'), ('He', 'All'), (',', 'of'), ('the', 'a'), ('car', 'sudden'), (',', 'the'), ('dog', 'wind'), ('was', 'picked'), ('her', 'up'), ('He', 'Sue'), ('was', 'bought'), ('the', 'an'), ('lot', 'alarm'), ('and', 'clock'), ('and', '.'), ('He', 'She'), ('very', 'living'), ('very', 'with'), ('the', 'her'), ('friends', 'parents'), ('was', 'ended'), ('a', 'up'), ('a', 'being'), ('a', 'late'), ('.', 'for'), ('the', 'work'), ('He', 'It'), ('a', 'nice'), ('.', 'and'), ('he', 'they'), ('had', 'were'), ('very', 'going'), ('go', 'pay'), ('He', 'So'), ('she', 'Bob'), ('was', 'and'), ('mother', 'son'), ('was', 'went'), ('the', 'a'), ('store', 'famous'), ('.', 'race'), ('.', 'course'), ('.', 'to'), ('the', 'watch'), ('.', 'one'), ('He', 'Bob'), ('was', 'even'), ('the', 'sat'), ('for', 'next'), ('and', 'to'), ('the', 'her'), ('store', '.'), ('He', 'Suddenly'), ('Bob', 'he'), ('was', 'noticed'), ('he', 'Bob'), ('was', 'outside'), ('to', 'with'), ('the', 'some'), ('.', 'other'), ('.', 'kids'), ('was', 'got'), ('a', 'in'), ('the', 'his'), ('store', 'car'), ('went', 'drove'), ('store', 'sports'), ('.', 'store'), ('He', 'She'), ('was', 'goes'), ('to', 'on'), ('the', 'a'), ('store', 'cruise'), ('and', 'every'), ('day', 'summer'), ('was', 'bought'), ('a', 'the'), ('lot', 'truck'), ('went', 'started'), ('to', 'his'), ('dog', 'business'), ('was', 'would'), ('not', 'practice'), ('to', 'all'), ('store', 'time'), ('He', 'So'), ('she', 'he'), ('was', 'challenged'), ('her', 'Bob'), ('to', ','), ('she', 'who'), ('very', 'the'), ('new', 'best'), ('time', '.'), ('He', 'Sue'), ('was', 'did'), ('have', 'want'), ('to', 'but'), ('he', 'went'), ('to', 'any'), ('the', 'way'), ('He', 'But'), ('was', 'knew'), ('she', 'how'), ('he', 'important'), ('a', 'this'), ('friends', 'would'), ('go', 'be'), ('.', 'to'), ('the', 'her'), ('friends', 'parents'), ('He', 'She'), ('was', 'decided'), ('go', 'try'), ('a', 'to'), ('go', 'return'), ('a', 'it'), ('He', 'She'), ('was', 'threw'), ('a', 'something'), ('to', 'together'), ('.', 'quickly'), ('.', 'and'), ('he', 'handed'), ('a', 'it'), ('.', 'in'), ('the', '. ...

# %%
import re,collections  
pre_tars = []
for word_s in  test_pre_tar:
    pre_tars.extend(word_s)   
pre_ters_fre = collections.Counter(pre_tars)
#pre_ters_fre = dict(pre_ters_fre)
pre_ters_fre = sorted(dict(pre_ters_fre).items(),key = lambda x:x[1],reverse = True)
print(pre_ters_fre[:35])
# Out:
# [(('He', 'Bob'), 141), (('He', 'She'), 112), (('He', 'Sue'), 89), (('.', 'to'), 69), (('was', 'had'), 57), (('.', 'and'), 52), (('the', 'her'), 50), (('was', 'decided'), 50), (('the', 'his'), 43), (('.', 'in'), 41), (('.', 'for'), 41), (('the', 'a'), 40), (('she', 'he'), 35), (('was', 'got'), 32), (('was', 'went'), 28), (('.', ','), 28), (('a', 'her'), 27), (('He', 'His'), 27), (('a', 'the'), 25), (('.', 'of'), 25), (('He', 'One'), 25), (('was', "'s"), 23), (('a', 'to'), 23), (('.', 'the'), 23), (('a', 'his'), 23), (('He', 'The'), 23), (('to', '.'), 23), (('the', 'it'), 22), (('to', 'he'), 22), (('He', 'But'), 21), (('a', 'it'), 21), (('He', 'Her'), 21), (('.', 'at'), 20), (('.', '!'), 20), (('was', 'wanted'), 20)]
